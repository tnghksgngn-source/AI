# %% [markdown]
# <a href="https://colab.research.google.com/github/tnghksgngn-source/AI/blob/main/week2_csncer_RF_C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
file_path = '/content/drive/MyDrive/breast_cancer.csv'
import pandas as pd
df = pd.read_csv(file_path)
df
import numpy as np
y = df['label']
y.value_counts()
X=df.drop('label',axis=1)
X.head()
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=0)
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

clf_lr = RandomForestClassifier(n_estimators=100, random_state=0)
clf_lr.fit(X_train, y_train)

pred_lr = clf_lr.predict(X_test)

print ("\n--- Logistic Regression Classifier ---")
print (accuracy_score(y_test, pred_lr))
print (confusion_matrix(y_test, pred_lr))
